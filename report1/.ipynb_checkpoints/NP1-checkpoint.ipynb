# %%
#import data
import numpy as np
import pandas as pd
import tensorflow as tf
import datetime as dt

data=pd.read_csv("train.csv")
Y_train= np.array(data["action_type"])
test_data=pd.read_csv("test.csv")
X_train = data.drop(columns=['action_type','shot_id','game_date'])
X_train["playoffs"]=X_train["playoffs"].astype("str")
X_train["period"]=X_train["period"].astype("str")
X_train["season"]=X_train["season"].astype("str")
X_train['shot_made_flag']=X_train['shot_made_flag'].astype("str")


X_train = pd.get_dummies(X_train, prefix=['period','playoffs', 'season', 'shot_made_flag',
                                          'shot_zone_area', 'opponent'])

X_train =np.array(X_train)

X_test = test_data.drop(columns=['shot_id','game_date'])
X_test["playoffs"]=X_test["playoffs"].astype("str")
X_test["period"]=X_test["period"].astype("str")
X_test["season"]=X_test["season"].astype("str")
X_test['shot_made_flag']=X_test['shot_made_flag'].astype("str")

X_test = pd.get_dummies(X_test, prefix=['period','playoffs', 'season', 'shot_made_flag',
                                          'shot_zone_area', 'opponent'])
X_test.insert(loc=13, column='period_7', value=0)
X_test =np.array(X_test)



''' Convert to one-hot encoding '''
from keras.utils import np_utils
Y_name ,Y_train_transform =np.unique(Y_train, return_inverse=True)
Y_train_transform = Y_train_transform.astype('int')
Y_train_transform = np_utils.to_categorical(Y_train_transform,57)

# %%
#import packages
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.optimizers import Adam, RMSprop, Adagrad ,adadelta
from keras.regularizers import l1,l2
from keras.callbacks import EarlyStopping
from keras.layers.core import Dropout
from keras.callbacks import Callback
from keras.layers.advanced_activations import LeakyReLU

#Self-defined Callbacks
class LossHistory(Callback):
    def on_train_begin(self, logs={}):
        self.loss = []
        self.acc = []
        self.val_loss = []
        self.val_acc = []
    def on_epoch_end(self, batch, logs={}):
        self.loss.append(logs.get('loss'))
        self.val_loss.append(logs.get('val_loss'))
        self.acc.append(logs.get('acc'))
        self.val_acc.append(logs.get('val_acc'))

#early stopping
earlyStopping=EarlyStopping(monitor= 'val_acc',
patience= 20)

#leakyRelu
lrelu= LeakyReLU(alpha = 0.02)

# %%
#DNN model
model=Sequential()
model.add(Dense(256, input_dim=78,kernel_regularizer=l1(0.01)))
model.add(Activation('relu'))
model.add(Dense(256,kernel_regularizer=l1(0.01)))
model.add(Activation('relu'))
model.add(Dense(256,kernel_regularizer=l1(0.01)))
model.add(Activation('relu'))
model.add(Dense(256,kernel_regularizer=l1(0.01)))
model.add(Activation('relu'))
model.add(Dense(256,kernel_regularizer=l1(0.01)))
model.add(Activation('relu'))
model.add(Dense(512,kernel_regularizer=l1(0.01)))
model.add(Activation('relu'))
model.add(Dense(512,kernel_regularizer=l1(0.01)))
model.add(Activation('relu'))
model.add(Dense(512,kernel_regularizer=l1(0.01)))
model.add(Activation('relu'))
model.add(Dense(512,kernel_regularizer=l1(0.01)))
model.add(Activation('relu'))
model.add(Dense(512,kernel_regularizer=l1(0.01)))
model.add(Activation('relu'))
model.add(Dense(1024,kernel_regularizer=l1(0.01)))
model.add(Activation('relu'))
model.add(Dense(1024,kernel_regularizer=l1(0.01)))
model.add(Activation('relu'))
model.add(Dense(1024,kernel_regularizer=l1(0.01)))
model.add(Activation('relu'))
model.add(Dense(1024,kernel_regularizer=l1(0.01)))
model.add(Activation('relu'))
model.add(Dense(1024,kernel_regularizer=l1(0.01)))
model.add(Activation('relu'))
model.add(Dense(2048,kernel_regularizer=l1(0.01)))
model.add(Activation('relu'))
model.add(Dense(2048,kernel_regularizer=l1(0.01)))
model.add(Activation('relu'))
model.add(Dense(2048,kernel_regularizer=l1(0.01)))
model.add(Activation('relu'))
model.add(Dense(2048,kernel_regularizer=l1(0.01)))
model.add(Activation('relu'))
model.add(Dense(2048,kernel_regularizer=l1(0.01)))
model.add(Activation('relu'))
model.add(Dense(57,kernel_regularizer=l1(0.01)))
model.add(Activation('softmax'))

#Setting optimizer as Adam
model.compile(loss= 'categorical_crossentropy',
                    optimizer='Adam',
                    metrics=['accuracy'])
loss_history = LossHistory()

# %%
#model fitting
history = model.fit(X_train, Y_train_transform,
                        batch_size=100,
                        epochs=300,
                        verbose=1,
                        shuffle=True,
                        validation_split=0.1,
                        callbacks=[loss_history,earlyStopping])
pred = model.predict_classes(X_test, verbose=0)
# Out:
# Train on 22101 samples, validate on 2456 samples
# Epoch 1/300
# 22101/22101 [==============================] - 14s 649us/step - loss: 499.7692 - acc: 0.6106 - val_loss: 34.0797 - val_acc: 0.6103
# Epoch 2/300
# 22101/22101 [==============================] - 12s 532us/step - loss: 33.4759 - acc: 0.6135 - val_loss: 33.2188 - val_acc: 0.6103
# Epoch 3/300
# 22101/22101 [==============================] - 12s 531us/step - loss: 33.1161 - acc: 0.6135 - val_loss: 33.4837 - val_acc: 0.6103
# Epoch 4/300
# 22101/22101 [==============================] - 12s 534us/step - loss: 32.9796 - acc: 0.6135 - val_loss: 33.0011 - val_acc: 0.6103
# Epoch 5/300
# 17800/22101 [=======================>......] - ETA: 2s - loss: 32.9344 - acc: 0.6108
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-de8cab6b5321> in <module>()
#       6                         shuffle=True,
# ...

# %%
#create output
final_pred=[]
for i in range(len(pred)):
    final_pred.append(Y_name[pred[i]])
output=pd.DataFrame()
output[0]=list(test_data['shot_id'])
output[1]=final_pred
output.to_csv('out.csv')

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_85 (Dense)             (None, 256)               20224
# _________________________________________________________________
# activation_85 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_86 (Dense)             (None, 256)               65792
# _________________________________________________________________
# activation_86 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_87 (Dense)             (None, 256)               65792
# _________________________________________________________________
# activation_87 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_88 (Dense)             (None, 256)               65792
# ...
