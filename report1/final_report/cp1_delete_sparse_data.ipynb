# %%
# import packages
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import matplotlib

# read data
data=pd.read_csv("E:/WORKOUT/Statistic/data_sciense_intro/report1/train.csv")

# %%
X_action_type = data['action_type'].value_counts()
X_action_type
# Out:
# Jump Shot                             15058
# Layup Shot                             2068
# Driving Layup Shot                     1579
# Fadeaway Jump Shot                      856
# Turnaround Jump Shot                    854
# Running Jump Shot                       746
# Pullup Jump shot                        387
# Turnaround Fadeaway shot                343
# Slam Dunk Shot                          333
# Reverse Layup Shot                      319
# Jump Bank Shot                          263
# Driving Dunk Shot                       241
# Dunk Shot                               211
# Tip Shot                                149
# Step Back Jump shot                     103
# Floating Jump shot                       92
# Alley Oop Dunk Shot                      90
# Driving Reverse Layup Shot               75
# Hook Shot                                70
# Driving Finger Roll Shot                 69
# Alley Oop Layup shot                     67
# Driving Finger Roll Layup Shot           63
# Reverse Dunk Shot                        62
# Running Layup Shot                       56
# Turnaround Bank shot                     53
# Running Bank shot                        42
# Driving Slam Dunk Shot                   40
# Running Hook Shot                        29
# Fadeaway Bank shot                       26
# Finger Roll Layup Shot                   22
# Driving Jump shot                        22
# Finger Roll Shot                         21
# Jump Hook Shot                           18
# Reverse Slam Dunk Shot                   14
# Running Dunk Shot                        14
# Pullup Bank shot                         12
# Driving Hook Shot                        12
# Turnaround Hook Shot                     11
# Putback Layup Shot                       10
# Running Reverse Layup Shot                9
# Follow Up Dunk Shot                       9
# Cutting Layup Shot                        6
# Running Pull-Up Jump Shot                 4
# Running Finger Roll Layup Shot            4
# Putback Dunk Shot                         3
# Hook Bank Shot                            3
# Driving Bank shot                         3
# Driving Floating Jump Shot                3
# Running Finger Roll Shot                  3
# Putback Slam Dunk Shot                    2
# Tip Layup Shot                            2
# Running Slam Dunk Shot                    1
# Cutting Finger Roll Layup Shot            1
# Turnaround Finger Roll Shot               1
# Turnaround Fadeaway Bank Jump Shot        1
# Running Tip Shot                          1
# Driving Floating Bank Jump Shot           1
# Name: action_type, dtype: int64

# %%
matplotlib.rcParams['figure.figsize'] = [15,10]
data['action_type'].value_counts().plot(kind='bar')

# %%
start = X_action_type.index.get_loc('Dunk Shot')
all_action_name = list(X_action_type.index)[start:57]
all_action_name
type(all_action_name)
# Out:
# list

# %%
data = data[~data.action_type.isin(all_action_name)]

# %%
matplotlib.rcParams['figure.figsize'] = [15,10]
data['action_type'].value_counts().plot(kind='bar')
